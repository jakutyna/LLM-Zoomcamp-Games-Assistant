# %%
from elasticsearch import Elasticsearch

ES_URL = "http://localhost:9200"

client = Elasticsearch(ES_URL)

client.get(index="games", id="1")
# Out:
# ObjectApiResponse({'_index': 'games', '_id': '1', '_version': 1, '_seq_no': 0, '_primary_term': 1, 'found': True, '_source': {'rank': 1, 'title': 'Clair Obscur: Expedition 33', 'genre': 'RPG', 'platforms': ['PC', 'PlayStation 5', 'Xbox Series X/S'], 'release_date': '2025-04-24', 'developer': 'Sandfall Interactive', 'publisher': 'Kepler Interactive', 'description': 'Clair Obscur: Expedition 33 is a turn-based role-playing game with real-time action elements, set in a dark fantasy world inspired by Belle Époque France. Players join Expedition 33, a group of volunteers sent on a desperate mission to stop the mysterious Paintress, a being who erases people from existence each year by painting a number. The game blends strategic party-based combat with timing-based attacks, dodges, and parries, emphasizing both planning and reflexes. It features a character-driven narrative, exploration, and a richly stylized visual presentation.'}})

# %%
client.search(index="games", query={"match": {"platforms": "PC"}})
# Out:
# ObjectApiResponse({'took': 4, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 174, 'relation': 'eq'}, 'max_score': 0.74128085, 'hits': [{'_index': 'games', '_id': '1', '_score': 0.74128085, '_source': {'rank': 1, 'title': 'Clair Obscur: Expedition 33', 'genre': 'RPG', 'platforms': ['PC', 'PlayStation 5', 'Xbox Series X/S'], 'release_date': '2025-04-24', 'developer': 'Sandfall Interactive', 'publisher': 'Kepler Interactive', 'description': 'Clair Obscur: Expedition 33 is a turn-based role-playing game with real-time action elements, set in a dark fantasy world inspired by Belle Époque France. Players join Expedition 33, a group of volunteers sent on a desperate mission to stop the mysterious Paintress, a being who erases people from existence each year by painting a number. The game blends strategic party-based combat with timing-based attacks, dodges, and parries, emphasizing both planning and reflexes. It features 
# ...
